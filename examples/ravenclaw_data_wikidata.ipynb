# %% [markdown]
# # ravenclaw.data.wikidata

# %%
from ravenclaw.data.wikidata import *

# %%
get_books(author='J. K. Rowling').head(9)
# Out:
#                                        id  \
# 0   http://www.wikidata.org/entity/Q43361
# 1   http://www.wikidata.org/entity/Q47209
# 2   http://www.wikidata.org/entity/Q47598
# 3   http://www.wikidata.org/entity/Q46751
# 4  http://www.wikidata.org/entity/Q194424
# 5  http://www.wikidata.org/entity/Q192258
# 6   http://www.wikidata.org/entity/Q80817
# 7   http://www.wikidata.org/entity/Q46887
# 8   http://www.wikidata.org/entity/Q46758
#
#                                        label         author        series  \
# 0   Harry Potter and the Philosopher's Stone  J. K. Rowling  Harry Potter
# 1    Harry Potter and the Chamber of Secrets  J. K. Rowling  Harry Potter
# 2   Harry Potter and the Prisoner of Azkaban  J. K. Rowling  Harry Potter
# 3        Harry Potter and the Goblet of Fire  J. K. Rowling  Harry Potter
# 4    Fantastic Beasts and Where to Find Them  J. K. Rowling  Harry Potter
# 5                 Quidditch Through the Ages  J. K. Rowling  Harry Potter
# ...

# %%
get_companies().head()
# Out:
#                                         id          company  \
# 0      http://www.wikidata.org/entity/Q248            Intel
# 1   http://www.wikidata.org/entity/Q568817   Digital Domain
# 2   http://www.wikidata.org/entity/Q906055             Orix
# 3  http://www.wikidata.org/entity/Q7243481        Primerica
# 4  http://www.wikidata.org/entity/Q7730196  Yuexiu Property
#
#                               exchange_id             exchange_name ticker
# 0   http://www.wikidata.org/entity/Q82059                    NASDAQ   INTC
# 1  http://www.wikidata.org/entity/Q496672  Hong Kong Stock Exchange   0547
# 2   http://www.wikidata.org/entity/Q13677   New York Stock Exchange     IX
# 3   http://www.wikidata.org/entity/Q13677   New York Stock Exchange    PRI
# 4  http://www.wikidata.org/entity/Q496672  Hong Kong Stock Exchange   0123

# %%
get_countries().head()
# Out:
#                                     id     country population code2 code3  \
# 0  http://www.wikidata.org/entity/Q399     Armenia    2976566    AM   ARM
# 1  http://www.wikidata.org/entity/Q672      Tuvalu       9876    TV   TUV
# 2  http://www.wikidata.org/entity/Q228     Andorra      79218    AD   AND
# 3  http://www.wikidata.org/entity/Q189     Iceland     332529    IS   ISL
# 4  http://www.wikidata.org/entity/Q227  Azerbaijan    9416801    AZ   AZE
#
#           latitude         longitude
# 0        40.383333             44.95
# 1           -7.475        178.005556
# 2  42.558333333333   1.5552777777778
# 3  64.830555555556  -17.986666666667
# 4             40.3              47.7

# %%
get_exchanges().head()
# Out:
#                                         id                         name  \
# 0  http://www.wikidata.org/entity/Q4437992       Spokane Stock Exchange
# 1  http://www.wikidata.org/entity/Q4438533       Midwest Stock Exchange
# 2  http://www.wikidata.org/entity/Q4470480           Ukrainian Exchange
# 3  http://www.wikidata.org/entity/Q4491711           NEX Stock Exchange
# 4  http://www.wikidata.org/entity/Q4491713  Stock Exchange of Mauritius
#
#   labels    country country_code2 country_code3 currency
# 0   None       None          None          None     None
# 1   None       None          None          None     None
# 2     UX    Ukraine            UA           UKR     None
# 3   None       None          None          None     None
# 4    SEM  Mauritius            MU           MUS     None
