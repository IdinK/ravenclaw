# %%
import polarbear.time as pt
from polarbear import display
from lonelypy.time import YearMonth

# %%
cal = pt.get_calendar(year=2016)
display(cal)
# Out:
#            date  year year_quarter  quarter year_month  month month_name  \
# 0    2016-01-01  2016      2016-01        1    2016-01      1    January
# 1    2016-01-02  2016      2016-01        1    2016-01      1    January
# 2    2016-01-03  2016      2016-01        1    2016-01      1    January
# 3    2016-01-04  2016      2016-01        1    2016-01      1    January
# 4    2016-01-05  2016      2016-01        1    2016-01      1    January
# 5    2016-01-06  2016      2016-01        1    2016-01      1    January
# 6    2016-01-07  2016      2016-01        1    2016-01      1    January
# 7    2016-01-08  2016      2016-01        1    2016-01      1    January
# 8    2016-01-09  2016      2016-01        1    2016-01      1    January
# 9    2016-01-10  2016      2016-01        1    2016-01      1    January
# 10   2016-01-11  2016      2016-01        1    2016-01      1    January
# 11   2016-01-12  2016      2016-01        1    2016-01      1    January
# ...

# %%
day1 = cal.iloc[0,:]

# %%
type(day1.year_quarter)
# Out:
# lonelypy.time.yearmonth.YearMonth

# %%
day1.year_quarter
# Out:
# 2016 carry:0 base:None | 1(start=1) carry:0 base:12

# %%
cal['year_month2'] = cal['year_monthname'].apply(lambda x: YearMonth(x=x, month_as='ful'))

# %%
display(cal)
# Out:
#            date  year year_quarter  quarter year_month  month month_name  \
# 0    2016-01-01  2016      2016-01        1    2016-01      1    January
# 1    2016-01-02  2016      2016-01        1    2016-01      1    January
# 2    2016-01-03  2016      2016-01        1    2016-01      1    January
# 3    2016-01-04  2016      2016-01        1    2016-01      1    January
# 4    2016-01-05  2016      2016-01        1    2016-01      1    January
# 5    2016-01-06  2016      2016-01        1    2016-01      1    January
# 6    2016-01-07  2016      2016-01        1    2016-01      1    January
# 7    2016-01-08  2016      2016-01        1    2016-01      1    January
# 8    2016-01-09  2016      2016-01        1    2016-01      1    January
# 9    2016-01-10  2016      2016-01        1    2016-01      1    January
# 10   2016-01-11  2016      2016-01        1    2016-01      1    January
# 11   2016-01-12  2016      2016-01        1    2016-01      1    January
# ...

# %%
cal['year_monthname'][0]
# Out:
# 2016 carry:0 base:None | 1(start=1) carry:0 base:12
