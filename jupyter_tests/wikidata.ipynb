# %%
from polarbear.data import wikidata as pw

# %%
pw.get_companies().head()
# Out:
#                                      id    company  \
# 0  http://www.wikidata.org/entity/Q2309    AvtoVAZ
# 1  http://www.wikidata.org/entity/Q2311  Airbus SE
# 2  http://www.wikidata.org/entity/Q2311  Airbus SE
# 3  http://www.wikidata.org/entity/Q2311  Airbus SE
# 4  http://www.wikidata.org/entity/Q6686    Renault
#
#                                exchange_id             exchange_name ticker
# 0  http://www.wikidata.org/entity/Q2632892           Moscow Exchange   AVAZ
# 1   http://www.wikidata.org/entity/Q842108                  Euronext    EAD
# 2   http://www.wikidata.org/entity/Q151139  Frankfurt Stock Exchange    EAD
# 3   http://www.wikidata.org/entity/Q617426           Bolsa de Madrid    EAD
# 4   http://www.wikidata.org/entity/Q842108                  Euronext    RNO

# %%
pw.get_countries().head()
# Out:
#                                     id     country population code2 code3  \
# 0  http://www.wikidata.org/entity/Q399     Armenia    2976566    AM   ARM
# 1  http://www.wikidata.org/entity/Q672      Tuvalu       9876    TV   TUV
# 2  http://www.wikidata.org/entity/Q228     Andorra      79218    AD   AND
# 3  http://www.wikidata.org/entity/Q189     Iceland     332529    IS   ISL
# 4  http://www.wikidata.org/entity/Q227  Azerbaijan    9416801    AZ   AZE
#
#           latitude         longitude
# 0        40.383333             44.95
# 1           -7.475        178.005556
# 2  42.558333333333   1.5552777777778
# 3  64.830555555556  -17.986666666667
# 4             40.3              47.7

# %%
pw.get_cities().head()
# Out:
#                                       id          city population  \
# 0  http://www.wikidata.org/entity/Q79339   Pilot Point         68
# 1  http://www.wikidata.org/entity/Q79346    Rainsville       4948
# 2  http://www.wikidata.org/entity/Q79349      Winfield       4717
# 3  http://www.wikidata.org/entity/Q79355  Greers Ferry        891
# 4  http://www.wikidata.org/entity/Q79357     Mount Ida       1076
#
#                            country_id                   country  \
# 0  http://www.wikidata.org/entity/Q30  United States of America
# 1  http://www.wikidata.org/entity/Q30  United States of America
# 2  http://www.wikidata.org/entity/Q30  United States of America
# 3  http://www.wikidata.org/entity/Q30  United States of America
# 4  http://www.wikidata.org/entity/Q30  United States of America
#
#           latitude           longitude
# 0          57.5603            -157.582
# 1        34.493254  -85.84653300000001
# 2        33.928258           -87.80799
# ...
