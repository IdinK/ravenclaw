# %%
from ravenclaw import ModelData
# Out:
# C:\code\idin\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'x1': [1,2,3,4], 'x2': [2,3,4,5], 'z1': [3,4,5,6], 'z2': [4,5,6,7], 'y':[5,6,7,np.nan]})
df = pd.concat([df]*2).reset_index(drop=True)
df['x1'] = [10,20,30,40,50,60,70,80]

# %%
df
# Out:
#    x1  x2    y  z1  z2
# 0  10   2  5.0   3   4
# 1  20   3  6.0   4   5
# 2  30   4  7.0   5   6
# 3  40   5  NaN   6   7
# 4  50   2  5.0   3   4
# 5  60   3  6.0   4   5
# 6  70   4  7.0   5   6
# 7  80   5  NaN   6   7

# %%
md = ModelData(X=df[['x1', 'x2']], y=df['y'], Z=df[['z1', 'z2']])

# %%
md.X
# Out:
#    x1  x2
# 0  10   2
# 1  20   3
# 2  30   4
# 3  40   5
# 4  50   2
# 5  60   3
# 6  70   4
# 7  80   5

# %%
md.select_valid_y().data
# Out:
#    x1  x2  z1  z2    y
# 0  10   2   3   4  5.0
# 1  20   3   4   5  6.0
# 2  30   4   5   6  7.0
# 3  50   2   3   4  5.0
# 4  60   3   4   5  6.0
# 5  70   4   5   6  7.0

# %%
md.select_invalid_y().data
# Out:
#    x1  x2  z1  z2   y
# 0  40   5   6   7 NaN
# 1  80   5   6   7 NaN

# %%
from sklearn.model_selection import RepeatedKFold

# %%
kfold = RepeatedKFold(n_repeats=3, n_splits=3, random_state=1)

# %%
train_indices, test_indices = md.split2(kfold)

# %%
train_indices
# Out:
# array([0, 3, 4, 5])

# %%
md.data
# Out:
#    x1  x2  z1  z2    y
# 0  10   2   3   4  5.0
# 1  20   3   4   5  6.0
# 2  30   4   5   6  7.0
# 3  40   5   6   7  NaN
# 4  50   2   3   4  5.0
# 5  60   3   4   5  6.0
# 6  70   4   5   6  7.0
# 7  80   5   6   7  NaN

# %%
valid_data = md.select_valid_y()
valid_data.data
# Out:
#    x1  x2  z1  z2    y
# 0  10   2   3   4  5.0
# 1  20   3   4   5  6.0
# 2  30   4   5   6  7.0
# 3  50   2   3   4  5.0
# 4  60   3   4   5  6.0
# 5  70   4   5   6  7.0

# %%
training_data = valid_data.select(indices=train_indices)
training_data.data
# Out:
#    x1  x2  z1  z2    y
# 0  10   2   3   4  5.0
# 1  50   2   3   4  5.0
# 2  60   3   4   5  6.0
# 3  70   4   5   6  7.0

# %%
test_data = valid_data.select(indices=test_indices)
test_data.data
# Out:
#    x1  x2  z1  z2    y
# 0  20   3   4   5  6.0
# 1  30   4   5   6  7.0

# %%
the_split = md.split(kfold=kfold)

# %%
the_split
# Out:
# <generator object ModelData.split at 0x000000001C15CBA0>

# %%
trainings = []
tests = []
invalids = []
train_indices_list = []
for training, test, invalid in the_split:
    trainings.append(training)
    tests.append(test)
    invalids.append(invalid)

# %%
i = 1

# %%
for i in range(4):
    print(i)
    display(invalids[i].data)
    display(trainings[i].data)
    display(tests[i].data)
    print('\n\n')
# Out:
# 0
#    x1  x2  z1  z2   y    set
# 0  40   5   6   7 NaN  extra
# 1  80   5   6   7 NaN  extra
#    x1  x2  z1  z2    y       set
# 0  10   2   3   4  5.0  training
# 1  50   2   3   4  5.0  training
# 2  60   3   4   5  6.0  training
# 3  70   4   5   6  7.0  training
#    x1  x2  z1  z2    y   set
# 0  20   3   4   5  6.0  test
# 1  30   4   5   6  7.0  test
# 1
#    x1  x2  z1  z2   y    set
# 0  40   5   6   7 NaN  extra
# 1  80   5   6   7 NaN  extra
#    x1  x2  z1  z2    y       set
# 0  20   3   4   5  6.0  training
# 1  30   4   5   6  7.0  training
# 2  50   2   3   4  5.0  training
# 3  70   4   5   6  7.0  training
#    x1  x2  z1  z2    y   set
# 0  10   2   3   4  5.0  test
# 1  60   3   4   5  6.0  test
# 2
#    x1  x2  z1  z2   y    set
# 0  40   5   6   7 NaN  extra
# 1  80   5   6   7 NaN  extra
#    x1  x2  z1  z2    y       set
# 0  10   2   3   4  5.0  training
# 1  20   3   4   5  6.0  training
# 2  30   4   5   6  7.0  training
# ...
